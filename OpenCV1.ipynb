# %%
#pip install opencv-python
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\hp\appdata\roaming\python\python311\site-packages (4.9.0.80)
# Requirement already satisfied: numpy>=1.21.2 in c:\programdata\anaconda3\lib\site-packages (from opencv-python) (1.24.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np

# %%
# Load an color image in grayscale
img = cv2.imread('sun.jpg',1)
img
# Out:
# array([[[168,  73,   0],
#         [168,  73,   0],
#         [168,  73,   0],
#         ...,
#         [172,  75,   1],
#         [172,  75,   1],
#         [172,  75,   1]],
#
#        [[168,  73,   0],
#         [168,  73,   0],
#         [168,  73,   0],
#         ...,
#         [172,  75,   1],
#         [172,  75,   1],
#         [172,  75,   1]],
#
#        [[168,  73,   0],
#         [168,  73,   0],
#         [168,  73,   0],
#         ...,
#         [172,  75,   1],
#         [172,  75,   1],
#         [172,  75,   1]],
#
#        ...,
#
#        [[216, 147, 114],
#         [215, 146, 113],
#         [215, 146, 113],
#         ...,
#         [216, 138,  95],
#         [216, 138,  95],
#         [216, 138,  95]],
#
#        [[216, 147, 114],
#         [215, 146, 113],
#         [215, 146, 113],
#         ...,
#         [216, 138,  95],
#         [216, 138,  95],
#         [216, 138,  95]],
#
#        [[216, 147, 114],
#         [215, 146, 113],
#         [215, 146, 113],
#         ...,
#         [216, 138,  95],
#         [216, 138,  95],
#         [216, 138,  95]]], dtype=uint8)

# %%
cv2.imshow('image',img)

# %%
print(img.shape)
print(img)
# Out:
# (236, 213, 3)
# [[[168  73   0]
#   [168  73   0]
#   [168  73   0]
#   ...
#   [172  75   1]
#   [172  75   1]
#   [172  75   1]]
#
#  [[168  73   0]
#   [168  73   0]
#   [168  73   0]
#   ...
#   [172  75   1]
#   [172  75   1]
#   [172  75   1]]
#
#  [[168  73   0]
#   [168  73   0]
#   [168  73   0]
#   ...
#   [172  75   1]
#   [172  75   1]
#   [172  75   1]]
#
#  ...
#
#  [[216 147 114]
#   [215 146 113]
#   [215 146 113]
#   ...
#   [216 138  95]
#   [216 138  95]
#   [216 138  95]]
#
#  [[216 147 114]
#   [215 146 113]
#   [215 146 113]
#   ...
#   [216 138  95]
#   [216 138  95]
#   [216 138  95]]
#
#  [[216 147 114]
#   [215 146 113]
#   [215 146 113]
#   ...
#   [216 138  95]
#   [216 138  95]
#   [216 138  95]]]

# %%
import matplotlib.pyplot as plt
plt.matshow(img)

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg',1)
plt.imshow(img, cmap = 'gray')
plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
plt.show()

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images
import matplotlib.pyplot as plt
import cv2  # computer vision library
# Read in the image
image = mpimg.imread('sun.jpg')

# Print out the image dimensions
print('Image dimensions:', image.shape)

# # Change from color to grayscale
gray_image = cv2.cvtColor(image, 0)
# plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis

plt.imshow(image)
# Out:
# Image dimensions: (236, 213, 3)

# %%
print(image)
# Out:
# [[[  0  73 170]
#   [  0  73 170]
#   [  0  73 170]
#   ...
#   [  1  75 172]
#   [  1  75 172]
#   [  1  75 172]]
#
#  [[  0  73 168]
#   [  0  73 168]
#   [  0  73 168]
#   ...
#   [  1  75 172]
#   [  1  75 172]
#   [  1  75 172]]
#
#  [[  0  73 168]
#   [  0  73 168]
#   [  0  73 168]
#   ...
#   [  1  75 172]
#   [  1  75 172]
#   [  1  75 172]]
#
#  ...
#
#  [[114 147 216]
#   [113 146 215]
#   [113 146 215]
#   ...
#   [ 95 138 216]
#   [ 95 138 216]
#   [ 95 138 216]]
#
#  [[114 147 216]
#   [113 146 215]
#   [113 146 215]
#   ...
#   [ 95 138 216]
#   [ 95 138 216]
#   [ 95 138 216]]
#
#  [[116 146 216]
#   [115 145 215]
#   [115 145 215]
#   ...
#   [ 95 138 216]
#   [ 95 138 216]
#   [ 95 138 216]]]

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
img = cv2.imread('sun.jpg',1)
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray_image,cmap = 'gray')
plt.title('Black in white Image'), plt.xticks([]), plt.yticks([])
# plt.imshow(img)
plt.show()
print(gray_image.shape)
print(img.shape)
# Out:
# (236, 213)
# (236, 213, 3)

# %%
print(gray_image)
# Out:
# [[ 62  62  62 ...  64  64  64]
#  [ 62  62  62 ...  64  64  64]
#  [ 62  62  62 ...  64  64  64]
#  ...
#  [145 144 144 ... 134 134 134]
#  [145 144 144 ... 134 134 134]
#  [145 144 144 ... 134 134 134]]

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[34, 20, 30, 150, 120],
                      [200, 200, 250, 70, 3],
                      [50, 180, 85, 40, 90],
                      [240, 100, 50, 255, 10],
                      [30, 0, 75, 190, 220]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0,255,0,255,0,255,0,255],
                      [255,0,255,0,255,0,255,0],
                      [0,255,0,255,0,255,0,255],
                      [255,0,255,0,255,0,255,0],
                      [0,255,0,255,0,255,0,255]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255],
                      [0,255,0,255,0,255,0,255]])

# To show the pixel grid, use matshow
plt.matshow(tiny_image, cmap='gray')

# %%
# Create a 5x5 image using just grayscale, numerical values
tiny_image = np.array([[[100,0,222], [0,255,255], [0,255,0]]])
# To show the pixel grid, use matshow
plt.matshow(tiny_image)

# %%
# Isolate RGB channels
r = img[:,:,0]
g = img[:,:,1]
b = img[:,:,2]
# # Visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.set_title('R channel')
ax1.imshow(r, cmap='gray')

ax2.set_title('G channel')
ax2.imshow(g, cmap='gray')

ax3.set_title('B channel')
ax3.imshow(b, cmap='gray')

# %%
# Isolate RGB channels
r = img[:,:,0]
g = img[:,:,1]
b = img[:,:,2]

# Visualize the individual color channels
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(20,10))
ax1.set_title('R channel')
ax1.imshow(r)

ax2.set_title('G channel')
ax2.imshow(g)

ax3.set_title('B channel')
ax3.imshow(b)

# %%
i = np.array([[[200,0,0], [231,0,0],[229,0,0] ,[255,0,0],[255,0,0],[255,0,0]]])
plt.matshow(i)
